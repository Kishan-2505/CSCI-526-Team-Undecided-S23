# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

response = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/',
    params={'q': 'requests+language:python'},
)
json_response_endless = response.json()

# %%
import requests

response = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/level5won',
    params={'q': 'requests+language:python'},
)
json_response_level1won = response.json()

response1 = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/level5lost',
    params={'q': 'requests+language:python'},
)
responselevel1 = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/retries',
    params={'q': 'requests+language:python'},
)
json_response_level1tot = responselevel1.json()


json_response_level1lost = response1.json()

# %%
json_response_level1tot['data']
# Out:
# [{'level': 'level1', 'count': 15},
#  {'level': 'level2', 'count': 414},
#  {'level': 'level3', 'count': 252},
#  {'level': 'level4', 'count': 50},
#  {'level': 'level5', 'count': 71}]

# %%
json_response_level1won['data']
# Out:
# [{'time': 20.92389678955078},
#  {'time': 8.598199844360352},
#  {'time': 10.657997131347656},
#  {'time': 23.892807006835938},
#  {'time': 23.313087463378906},
#  {'time': 14.056594848632812},
#  {'time': 13.393302917480469},
#  {'time': 13.364097595214844},
#  {'time': 22.319900512695312},
#  {'time': 23.639389038085938},
#  {'time': 11.903999328613281},
#  {'time': 16.464099884033203},
#  {'time': 13.7886962890625},
#  {'time': 20.9696044921875},
#  {'time': 10.575996398925781},
#  {'time': 18.769001007080078},
#  {'time': 12.918899536132812},
#  {'time': 11.655299186706543},
#  {'time': 30.435195922851562},
#  {'time': 37.97559356689453},
#  {'time': 22.828277587890625},
#  {'time': 14.436800003051758},
#  {'time': 22.871997833251953},
#  {'time': 21.577999114990234},
#  {'time': 11.792898178100586},
#  {'time': 11.5513916015625},
#  {'time': 41.212100982666016},
#  {'time': 17.320892333984375},
#  {'time': 9.931098937988281},
#  {'time': 28.826499938964844},
#  {'time': 17.78900146484375},
#  {'time': 17.52099609375},
#  {'time': 18.960895538330078},
#  {'time': 23.62319564819336},
#  {'time': 11.477899551391602},
#  {'time': 17.635986328125},
#  {'time': 12.718097686767578},
#  {'time': 11.027799606323242},
#  {'time': 10.807899475097656},
#  {'time': 23.615997314453125},
#  {'time': 8.705001831054688},
#  {'time': 16.413997650146484},
#  {'time': 11.8717041015625},
#  {'time': 16.9053955078125},
#  {'time': 8.911197662353516},
#  {'time': 30.35369873046875},
#  {'time': 11.281497955322266},
#  {'time': 17.870162963867188},
#  {'time': 14.490798950195312},
#  {'time': 12.00799560546875},
#  {'time': 17.91899871826172},
#  {'time': 17.20840072631836},
#  {'time': 13.41689682006836},
#  {'time': 14.133996963500977},
#  {'time': 14.931598663330078},
#  {'time': 26.59479522705078},
#  {'time': 27.17020034790039},
#  {'time': 22.909099578857422},
#  {'time': 16.964996337890625},
#  {'time': 21.53399658203125},
#  {'time': 10.512405395507812},
#  {'time': 14.515998840332031},
#  {'time': 17.452392578125},
#  {'time': 54.654701232910156},
#  {'time': 26.97100067138672},
#  {'time': 16.469390869140625},
#  {'time': 16.475297927856445},
#  {'time': 19.187698364257812},
#  {'time': 9.458998680114746},
#  {'time': 13.579299926757812},
#  {'time': 15.198399543762207},
#  {'time': 18.330902099609375},
#  {'time': 20.298198699951172},
#  {'time': 17.653797149658203},
#  {'time': 24.19769287109375},
#  {'time': 22.527599334716797},
#  {'time': 22.5679988861084},
#  {'time': 13.74789810180664},
#  {'time': 22.356796264648438},
#  {'time': 18.128692626953125},
#  {'time': 20.634498596191406},
#  {'time': 14.196502685546875},
#  {'time': 29.91796875},
#  {'time': 22.75738525390625},
#  {'time': 19.80809783935547},
#  {'time': 12.002098083496094},
#  {'time': 18.31188201904297},
#  {'time': 24.595306396484375},
#  {'time': 25.535968780517578},
#  {'time': 15.678998947143555},
#  {'time': 12.86130142211914},
#  {'time': 19.82769775390625},
#  {'time': 18.103195190429688},
#  {'time': 18.628700256347656},
#  {'time': 26.39089584350586},
#  {'time': 11.86920166015625},
#  {'time': 18.753097534179688},
#  {'time': 13.1506986618042},
#  {'time': 16.574005126953125}]

# %%
len(json_response_level1won['data'])+len(json_response_level1lost['data'])
# Out:
# 137

# %% [raw]
# '''0 is when u die cuz of enemy 1-starvation 2-win'''

# %%
import matplotlib.pyplot as plt

list_of_dicts = json_response_endless['data']
cause_of_death_counts = [dict_['causeOfDeath'] for dict_ in list_of_dicts]

cause_0_count = cause_of_death_counts.count(0)
cause_1_count = cause_of_death_counts.count(1)

labels = ['Enemy', 'Size']
sizes = [cause_0_count, cause_1_count]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')

plt.show()

# %%
len(json_response_endless['data'])
# Out:
# 65

# %%
'''
Traverse a list of dictionaries in python of type:
[{'score': 5, 'time': 15, 'causeOfDeath': 1},
 {'causeOfDeath': 0, 'score': 6, 'time': 1}]
Create a bar plot of the count of time duration of the game with respect to time with each bar being 5 units of time. Each bar should be a different colour'''
# Out:
# "\nTraverse a list of dictionaries in python of type:\n[{'score': 5, 'time': 15, 'causeOfDeath': 1},\n {'causeOfDeath': 0, 'score': 6, 'time': 1}]\nCreate a bar plot of the count of time duration of the game with respect to time with each bar being 5 units of time. Each bar should be a different colour"

# %%
import matplotlib.pyplot as plt

data = json_response_endless['data']

times = [d['time'] for d in data]
plt.hist(times, bins=5, color=['lightblue'],ec="green")
plt.xlim([0, 1000])
plt.ylim([0, 40])
plt.xlabel('Time')
plt.ylabel('Count')

plt.show()

# %%
import matplotlib.pyplot as plt

data = json_response_endless['data']

times = [d['time'] for d in data]
plt.hist(times, color=['lightblue'],ec="green")
plt.xlim([0, 100])
plt.ylim([0, 200])
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()

# %%
#Level1

# %%
import requests


response = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/level1won',
    params={'q': 'requests+language:python'},
)
response2 = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/level1lost',
    params={'q': 'requests+language:python'},
)
json_response_level1won = response.json()
json_response_level1lost = response2.json()

# %%
json_response_level1['data']
# Out:
# [{'causeOfDeath': 3, 'score': 19, 'isGettingSmall': False, 'time': 200},
#  {'causeOfDeath': 3, 'time': 500, 'isGettingSmall': False, 'score': 2},
#  {'causeOfDeath': 3, 'time': 600, 'score': 8, 'isGettingSmall': False},
#  {'time': 1000, 'score': 18, 'isGettingSmall': False, 'causeOfDeath': 3},
#  {'score': 0, 'time': 490, 'isGettingSmall': False, 'causeOfDeath': 3},
#  {'causeOfDeath': 0,
#   'time': 3.3245997428894043,
#   'score': 0,
#   'isGettingSmall': True},
#  {'time': 13.11620044708252,
#   'score': 1,
#   'causeOfDeath': 1,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 4.294099807739258,
#   'score': 0},
#  {'score': 2,
#   'isGettingSmall': True,
#   'time': 8.766999244689941,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 1,
#   'time': 9.42919921875},
#  {'time': 25.234600067138672,
#   'causeOfDeath': 1,
#   'score': 2,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 5.331199645996094},
#  {'score': 3,
#   'time': 19.179298400878906,
#   'isGettingSmall': True,
#   'causeOfDeath': 1},
#  {'causeOfDeath': 0,
#   'time': 86.46019744873047,
#   'isGettingSmall': True,
#   'score': 14},
#  {'time': 17.509788513183594,
#   'isGettingSmall': True,
#   'score': 3,
#   'causeOfDeath': 0},
#  {'isGettingSmall': False,
#   'time': 139.05810546875,
#   'causeOfDeath': 3,
#   'score': 5},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 5.942999839782715,
#   'score': 1},
#  {'score': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 1,
#   'time': 9.994999885559082},
#  {'score': 0,
#   'time': 10.011999130249023,
#   'isGettingSmall': True,
#   'causeOfDeath': 1},
#  {'causeOfDeath': 0,
#   'time': 8.605998992919922,
#   'isGettingSmall': True,
#   'score': 2},
#  {'time': 52.163002014160156,
#   'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'score': 2},
#  {'time': 6.601900100708008,
#   'causeOfDeath': 0,
#   'score': 1,
#   'isGettingSmall': True},
#  {'time': 59.31959533691406,
#   'score': 7,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'score': 1,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 8.207099914550781},
#  {'time': 6.252199172973633,
#   'score': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'time': 6.235799789428711,
#   'causeOfDeath': 0,
#   'score': 1,
#   'isGettingSmall': True},
#  {'time': 19.137500762939453,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': 1},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 0,
#   'time': 2.9967002868652344},
#  {'time': 10.070999145507812,
#   'score': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 1},
#  {'causeOfDeath': 1,
#   'score': 4,
#   'isGettingSmall': True,
#   'time': 22.17040252685547},
#  {'score': 3,
#   'time': 55.45359802246094,
#   'causeOfDeath': 1,
#   'isGettingSmall': True},
#  {'time': 15.860992431640625,
#   'isGettingSmall': True,
#   'score': 2,
#   'causeOfDeath': 0},
#  {'score': 13,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 33.080780029296875},
#  {'causeOfDeath': 0,
#   'score': 5,
#   'isGettingSmall': True,
#   'time': 20.42599868774414},
#  {'causeOfDeath': 0,
#   'time': 6.486991882324219,
#   'score': 2,
#   'isGettingSmall': True},
#  {'time': 18.459999084472656,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 6},
#  {'time': 24.0419921875,
#   'causeOfDeath': 0,
#   'score': 8,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'time': 7.609992980957031,
#   'causeOfDeath': 0,
#   'score': 1},
#  {'score': 0,
#   'time': 4.22900390625,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'score': 2,
#   'time': 34.91999816894531,
#   'isGettingSmall': True,
#   'causeOfDeath': 1},
#  {'time': 50.066993713378906,
#   'score': 1,
#   'isGettingSmall': True,
#   'causeOfDeath': 3},
#  {'causeOfDeath': 0,
#   'score': 3,
#   'time': 14.702899932861328,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 16.76409912109375,
#   'score': 4},
#  {'isGettingSmall': True,
#   'causeOfDeath': 1,
#   'time': 22.279800415039062,
#   'score': 4},
#  {'isGettingSmall': True,
#   'time': 4.363990783691406,
#   'causeOfDeath': 0,
#   'score': 1},
#  {'score': 1,
#   'time': 11.7969970703125,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'score': 4,
#   'isGettingSmall': True,
#   'time': 31.326904296875},
#  {'score': 0,
#   'causeOfDeath': 1,
#   'time': 10.083206176757812,
#   'isGettingSmall': True},
#  {'time': 13.116897583007812,
#   'score': 1,
#   'isGettingSmall': True,
#   'causeOfDeath': 1},
#  {'time': 66.4280014038086,
#   'isGettingSmall': True,
#   'causeOfDeath': 3,
#   'score': 4},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 10,
#   'time': 25.895998001098633},
#  {'score': 4,
#   'causeOfDeath': 0,
#   'time': 15.030998229980469,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 35.92020034790039,
#   'score': 2},
#  {'causeOfDeath': 1,
#   'score': 15,
#   'isGettingSmall': True,
#   'time': 56.55400085449219},
#  {'score': 0,
#   'isGettingSmall': True,
#   'time': 3.3002381324768066,
#   'causeOfDeath': 0},
#  {'score': 4,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 14.528999328613281},
#  {'score': 0,
#   'time': 39.328704833984375,
#   'isGettingSmall': True,
#   'causeOfDeath': 3},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 7.57819938659668,
#   'score': 0},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'score': 7,
#   'time': 31.30350112915039},
#  {'score': 2,
#   'isGettingSmall': True,
#   'causeOfDeath': 1,
#   'time': 16.151199340820312},
#  {'causeOfDeath': 0,
#   'score': 2,
#   'isGettingSmall': True,
#   'time': 7.94529914855957},
#  {'causeOfDeath': 0,
#   'score': 5,
#   'time': 25.05809783935547,
#   'isGettingSmall': True},
#  {'causeOfDeath': 1,
#   'time': 10.022132873535156,
#   'score': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'time': 30.45979881286621,
#   'score': 5,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'time': 1.997426986694336,
#   'isGettingSmall': True},
#  {'score': 1,
#   'isGettingSmall': True,
#   'time': 7.616900444030762,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'score': 7,
#   'isGettingSmall': True,
#   'time': 17.144500732421875},
#  {'time': 5.87999963760376,
#   'isGettingSmall': True,
#   'score': 2,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'time': 11.15999984741211,
#   'isGettingSmall': True,
#   'score': 4},
#  {'isGettingSmall': True,
#   'time': 1.9799998998641968,
#   'causeOfDeath': 0,
#   'score': 0},
#  {'causeOfDeath': 0,
#   'time': 2.0511159896850586,
#   'score': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'time': 7.559999942779541,
#   'causeOfDeath': 0,
#   'score': 3},
#  {'time': 9.541299819946289,
#   'score': 2,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'time': 39.156898498535156,
#   'score': 11,
#   'isGettingSmall': True},
#  {'score': 1,
#   'causeOfDeath': 0,
#   'time': 5.621700286865234,
#   'isGettingSmall': True},
#  {'time': 2.319999933242798,
#   'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'time': 15.289823532104492,
#   'score': 5,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 2.3999998569488525},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 2.0799999237060547},
#  {'isGettingSmall': True,
#   'time': 9.78712272644043,
#   'causeOfDeath': 1,
#   'score': 0},
#  {'time': 5.922296524047852,
#   'causeOfDeath': 0,
#   'score': 1,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'time': 5.048789978027344,
#   'score': 1,
#   'causeOfDeath': 0},
#  {'time': 33.54667282104492,
#   'isGettingSmall': True,
#   'score': 6,
#   'causeOfDeath': 0},
#  {'score': 0,
#   'time': 38.48767852783203,
#   'isGettingSmall': True,
#   'causeOfDeath': 3},
#  {'causeOfDeath': 1,
#   'time': 10.00053596496582,
#   'score': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 1,
#   'score': 0,
#   'time': 9.993993759155273,
#   'isGettingSmall': True},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'time': 19.003570556640625,
#   'score': 3},
#  {'causeOfDeath': 3,
#   'score': 0,
#   'time': 110.54000091552734,
#   'isGettingSmall': False},
#  {'time': 17.26386260986328,
#   'score': 7,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 10.029263496398926},
#  {'isGettingSmall': True,
#   'causeOfDeath': 1,
#   'time': 10.110817909240723,
#   'score': 0},
#  {'score': 1,
#   'time': 11.157586097717285,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 10.000371932983398},
#  {'time': 11.626100540161133,
#   'score': 3,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'time': 7.86039924621582,
#   'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 1,
#   'score': 0,
#   'time': 10.124500274658203,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 11.75999927520752,
#   'score': 4},
#  {'causeOfDeath': 0,
#   'score': 5,
#   'time': 70.22000122070312,
#   'isGettingSmall': False},
#  {'causeOfDeath': 0,
#   'time': 1.6799999475479126,
#   'score': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': 0,
#   'time': 2.0199999809265137},
#  {'causeOfDeath': 0,
#   'time': 2.5399999618530273,
#   'score': 0,
#   'isGettingSmall': True},
#  {'time': 1.6999999284744263,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 0},
#  {'score': 2,
#   'isGettingSmall': True,
#   'time': 6.579999923706055,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'time': 18.937044143676758,
#   'score': 3},
#  {'time': 24.058879852294922,
#   'causeOfDeath': 0,
#   'score': 9,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'time': 2.2197341918945312},
#  {'time': 5.460000038146973,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 0},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 0,
#   'time': 5.460000038146973},
#  {'score': 0,
#   'causeOfDeath': 0,
#   'time': 1.659999966621399,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'score': 3,
#   'isGettingSmall': True,
#   'time': 9.749465942382812},
#  {'causeOfDeath': 0,
#   'time': 11.782233238220215,
#   'isGettingSmall': True,
#   'score': 2},
#  {'score': 1,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 6.839999675750732},
#  {'causeOfDeath': 0,
#   'time': 89.23579406738281,
#   'isGettingSmall': False,
#   'score': 8},
#  {'time': 15.404499053955078,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 7},
#  {'time': 4.311100006103516,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'score': 3,
#   'isGettingSmall': True,
#   'time': 19.149900436401367},
#  {'score': 0,
#   'isGettingSmall': True,
#   'time': 4.41309928894043,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'time': 5.332900047302246,
#   'isGettingSmall': True},
#  {'time': 7.576198577880859,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 1},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 8.149894714355469},
#  {'isGettingSmall': True,
#   'score': 5,
#   'causeOfDeath': 0,
#   'time': 11.37469482421875},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 1.3473210334777832,
#   'score': 0},
#  {'causeOfDeath': 1,
#   'score': 0,
#   'time': 9.40389633178711,
#   'isGettingSmall': True},
#  {'time': 1.8406977653503418,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 1},
#  {'causeOfDeath': 3,
#   'time': 102.27200317382812,
#   'score': 0,
#   'isGettingSmall': False},
#  {'score': 0,
#   'causeOfDeath': 1,
#   'time': 10.12860107421875,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 1.9591064453125},
#  {'causeOfDeath': 0,
#   'score': 12,
#   'isGettingSmall': False,
#   'time': 96.02279663085938},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 19.48499870300293,
#   'score': 6},
#  {'causeOfDeath': 0,
#   'score': 16,
#   'isGettingSmall': True,
#   'time': 67.14909362792969},
#  {'time': 42.24100112915039,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 11},
#  {'score': 11,
#   'causeOfDeath': 0,
#   'time': 38.055999755859375,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'time': 10.805999755859375,
#   'causeOfDeath': 0,
#   'score': 2},
#  {'causeOfDeath': 1,
#   'time': 10.185998916625977,
#   'isGettingSmall': True,
#   'score': 0},
#  {'score': 0,
#   'isGettingSmall': True,
#   'time': 3.929999828338623,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'time': 46.038002014160156,
#   'score': 5},
#  {'isGettingSmall': True,
#   'time': 19.081993103027344,
#   'score': 3,
#   'causeOfDeath': 1},
#  {'time': 19.26519775390625,
#   'causeOfDeath': 1,
#   'score': 3,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'score': 8,
#   'causeOfDeath': 0,
#   'time': 23.20979881286621},
#  {'time': 42.080101013183594,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 6},
#  {'causeOfDeath': 3,
#   'time': 109.56959533691406,
#   'score': 1,
#   'isGettingSmall': False},
#  {'time': 1.659999966621399,
#   'score': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'time': 19.703697204589844,
#   'isGettingSmall': True,
#   'score': 0},
#  {'score': 2,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 9.234399795532227},
#  {'score': 8,
#   'time': 20.25139617919922,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'time': 13.020698547363281,
#   'causeOfDeath': 0,
#   'score': 2},
#  {'score': 15,
#   'causeOfDeath': 0,
#   'time': 42.19740295410156,
#   'isGettingSmall': True},
#  {'score': 3,
#   'time': 7.4053955078125,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'time': 31.738372802734375,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 11},
#  {'time': 24.18267822265625,
#   'isGettingSmall': True,
#   'score': 9,
#   'causeOfDeath': 0},
#  {'score': 1,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 5.367999076843262},
#  {'time': 19.433000564575195,
#   'score': 3,
#   'causeOfDeath': 1,
#   'isGettingSmall': True},
#  {'score': 0,
#   'time': 4.296298980712891,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 7,
#   'time': 93.72489929199219},
#  {'time': 34.78630065917969,
#   'isGettingSmall': True,
#   'causeOfDeath': 3,
#   'score': 0},
#  {'causeOfDeath': 3,
#   'time': 128.35427856445312,
#   'score': 13,
#   'isGettingSmall': False},
#  {'score': 1,
#   'causeOfDeath': 0,
#   'time': 2.924999713897705,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'time': 14.817998886108398,
#   'isGettingSmall': True,
#   'score': 4}]

# %%
len(json_response_level1['data'])
# Out:
# 158

# %%
import matplotlib.pyplot as plt

data = json_response_level1['data']

# initialize the counter for each cause of death
causeOfDeath_0_count = 0
causeOfDeath_1_count = 0
causeOfDeath_3_count = 0

# count the number of deaths for each cause of death
for d in data:
    if d['causeOfDeath'] == 0:
        causeOfDeath_0_count += 1
    elif d['causeOfDeath'] == 1:
        causeOfDeath_1_count += 1

# create a list of the counts for each cause of death
counts = [causeOfDeath_0_count, causeOfDeath_1_count]

# create a list of the labels for each cause of death
labels = ['Enemy', 'Size']

# create a list of colors for the pie chart
colors = ['red', 'green']

# create the pie chart
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# add a title to the chart
plt.title('Causes of Death')

# show the chart
plt.show()

# %%
import matplotlib.pyplot as plt

list_of_dicts = json_response_level1['data']
cause_of_death_counts = [dict_['causeOfDeath'] for dict_ in list_of_dicts]

cause_0_count = cause_of_death_counts.count(0)
cause_1_count = cause_of_death_counts.count(1)

labels = ['Enemy', 'Size']
sizes = [cause_0_count, cause_1_count]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')

plt.show()

# %%
import matplotlib.pyplot as plt

# Filter the data based on causeOfDeath field
causeOfDeath01 = [d['time'] for d in json_response_level1['data'] if d['causeOfDeath'] in [0, 1]]
causeOfDeath3 = [d['time'] for d in json_response_level1['data'] if d['causeOfDeath'] == 3]

# Set the bin size and range for the histogram
bin_size = 20
range_min = min(min(causeOfDeath01), min(causeOfDeath3))
range_max = max(max(causeOfDeath01), max(causeOfDeath3))

# Create two separxate histograms
fig, (ax1, ax2) = plt.subplots(2, 1,figsize=(10, 8))

ax1.hist(causeOfDeath01, bins=int((range_max-range_min)/bin_size), range=(range_min, range_max), color='green',edgecolor='black')
ax1.set_title('Histogram for causeOfDeath=0 or 1')
ax1.set_xlabel('Time')
ax1.set_ylabel('Count')
ax1.set_xlim(0, 150)
ax1.set_ylim(0, 150)

ax2.hist(causeOfDeath3, bins=int((range_max-range_min)/bin_size), range=(range_min, range_max), color='blue', edgecolor='black')
ax2.set_title('Histogram for Winning')
ax2.set_xlabel('Time')
ax2.set_ylabel('Count')
ax2.set_xlim(0, 150)
ax2.set_ylim(0, 30)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# sample data
data = json_response_level1['data']
# filter data
filtered_data = [d for d in data if d.get('causeOfDeath') == 3]

# calculate percentages
num_true = sum(1 for d in filtered_data if d.get('isGettingSmall') is True)
num_false = sum(1 for d in filtered_data if d.get('isGettingSmall') is False)
total = num_true + num_false
percent_true = num_true / total * 100
percent_false = num_false / total * 100

# plot pie chart
fig, ax = plt.subplots()
ax.pie([percent_true, percent_false], labels=['Shrinking', 'Infinite health'], autopct='%1.1f%%')
ax.set_title('Percentage Winning of players Shrinking or have Infinite health ')
plt.show()

# %%
import matplotlib.pyplot as plt

data = json_response_level1['data']

# Create two lists to hold the x and y values for the plot
x_vals = []
y_vals = []

# Create two lists to hold the colors for each point based on causeOfDeath
colors = []

for entry in data:
    if entry['causeOfDeath'] == 0 or entry['causeOfDeath'] == 1:
        colors.append('blue')
    elif entry['causeOfDeath'] == 3:
        colors.append('red')
#     else:
#         colors.append('black')

    x_vals.append(entry['time'])
    y_vals.append(entry['score'])

# Create the scatter plot with time and score as axes
plt.scatter(x_vals, y_vals, c=colors)

# Add axis labels and a title
plt.xlabel('Time')
plt.ylabel('Score')
plt.title('Score vs. Time with Win State')

# Add a legend for the causeOfDeath categories
# plt.legend(['causeOfDeath = 0', 'causeOfDeath = 1'])
plt.legend(['Cause of death = 0', 'Cause of death = 1'])
 
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

data = json_response_level1['data']

# Create lists to hold the x and y values for each category
x_vals_0 = []
y_vals_0 = []
x_vals_1 = []
y_vals_1 = []
x_vals_3 = []
y_vals_3 = []
plt.figure(figsize=(9, 7))

# Populate the lists based on the value of causeOfDeath
for entry in data:
    if entry['causeOfDeath'] == 0:
        x_vals_0.append(entry['time'])
        y_vals_0.append(entry['score'])
    elif entry['causeOfDeath'] == 1:
        x_vals_1.append(entry['time'])
        y_vals_1.append(entry['score'])
    elif entry['causeOfDeath'] == 3:
        x_vals_3.append(entry['time'])
        y_vals_3.append(entry['score'])

# Create the scatter plots for each category
scatter_0 = plt.scatter(x_vals_0, y_vals_0, c='blue', label='Enemy Attack')
scatter_1 = plt.scatter(x_vals_1, y_vals_1, c='green', label='Diminshed Size')
scatter_3 = plt.scatter(x_vals_3, y_vals_3, c='red', label='Winners')

# Add axis labels and a title
plt.xlabel('Time')
plt.ylabel('Score')
plt.title('Score vs. Time with Win State')
plt.xlim(0, 120)

# Add a legend for the causeOfDeath categories
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles, labels=labels)

# Display the plot
plt.show()

# %%
#Level2

# %%
import requests

response = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/level2won',
    params={'q': 'requests+language:python'},
)
response2 = requests.get(
    'https://rich-teal-crayfish-coat.cyclic.app/level1lost',
    params={'q': 'requests+language:python'},
)
json_response_level1won = response.json()
json_response_level1lost = response2.json()

# %%
json_response_level2['data']
# Out:
# [{'score': 33,
#   'time': 100.6897964477539,
#   'bulletHit': 1,
#   'causeOfDeath': 0,
#   'isGettingSmall': False,
#   'bulletsFired': 3},
#  {'isGettingSmall': False,
#   'bulletHit': 4,
#   'time': 84.3240966796875,
#   'bulletsFired': 7,
#   'score': 24,
#   'causeOfDeath': 3},
#  {'score': 0,
#   'time': 8.42889404296875,
#   'bulletsFired': 1,
#   'causeOfDeath': 0,
#   'isGettingSmall': False,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': False,
#   'time': 23.01800537109375,
#   'bulletsFired': 0,
#   'score': 9,
#   'causeOfDeath': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': False,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'score': 2,
#   'time': 7.9207000732421875},
#  {'score': 0,
#   'bulletHit': 4,
#   'time': 14.390106201171875,
#   'isGettingSmall': False,
#   'bulletsFired': 4,
#   'causeOfDeath': 3},
#  {'time': 4.188507080078125,
#   'isGettingSmall': False,
#   'score': 1,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': 0},
#  {'score': 2,
#   'isGettingSmall': False,
#   'bulletsFired': 5,
#   'causeOfDeath': 1,
#   'bulletHit': 3,
#   'time': 23.3314208984375},
#  {'bulletHit': 0,
#   'score': 6,
#   'time': 28.26559829711914,
#   'causeOfDeath': 1,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 4.296901702880859,
#   'bulletHit': 0},
#  {'causeOfDeath': 0,
#   'time': 15.975700378417969,
#   'bulletHit': 0,
#   'score': 0,
#   'bulletsFired': 1,
#   'isGettingSmall': True},
#  {'time': 4.311798095703125,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True},
#  {'time': 8.963699340820312,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 1},
#  {'time': 5.302101135253906,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 0},
#  {'bulletHit': 0,
#   'time': 11.798393249511719,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 3},
#  {'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 8,
#   'time': 31.730798721313477},
#  {'causeOfDeath': 1,
#   'score': 1,
#   'isGettingSmall': True,
#   'time': 20.268096923828125,
#   'bulletHit': 2,
#   'bulletsFired': 5},
#  {'time': 70.50430297851562,
#   'isGettingSmall': False,
#   'causeOfDeath': 3,
#   'score': 3,
#   'bulletsFired': 6,
#   'bulletHit': 4},
#  {'bulletsFired': 19,
#   'bulletHit': 4,
#   'time': 201.71319580078125,
#   'causeOfDeath': 3,
#   'isGettingSmall': False,
#   'score': 7},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'bulletsFired': 1,
#   'time': 12.131378173828125,
#   'score': 0,
#   'bulletHit': 1},
#  {'score': 0,
#   'bulletsFired': 12,
#   'bulletHit': 4,
#   'time': 92.88381958007812,
#   'isGettingSmall': False,
#   'causeOfDeath': 3},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'time': 46.170997619628906,
#   'score': 19,
#   'bulletsFired': 0,
#   'isGettingSmall': False},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 0,
#   'bulletsFired': 4,
#   'time': 16.033004760742188,
#   'causeOfDeath': 1},
#  {'causeOfDeath': 1,
#   'score': 3,
#   'bulletsFired': 3,
#   'time': 24.02301025390625,
#   'isGettingSmall': True,
#   'bulletHit': 1},
#  {'isGettingSmall': True,
#   'score': 1,
#   'bulletsFired': 4,
#   'bulletHit': 0,
#   'time': 19.019012451171875,
#   'causeOfDeath': 1},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'time': 16.016006469726562,
#   'score': 0,
#   'bulletsFired': 4,
#   'bulletHit': 2},
#  {'isGettingSmall': True,
#   'bulletsFired': 5,
#   'bulletHit': 0,
#   'time': 17.735000610351562,
#   'causeOfDeath': 1,
#   'score': 0},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 2,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 5.0260009765625},
#  {'score': 0,
#   'bulletsFired': 1,
#   'isGettingSmall': False,
#   'bulletHit': 0,
#   'time': 19.52910041809082,
#   'causeOfDeath': 3},
#  {'time': 11.391298294067383,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 2,
#   'bulletsFired': 0,
#   'time': 5.992900848388672,
#   'isGettingSmall': False},
#  {'causeOfDeath': 0,
#   'time': 21.73599624633789,
#   'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': False,
#   'bulletHit': 0},
#  {'bulletHit': 3,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 8,
#   'score': 31,
#   'time': 108.42469024658203},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'score': 3,
#   'bulletHit': 0,
#   'time': 9.214393615722656},
#  {'isGettingSmall': True,
#   'score': 11,
#   'bulletsFired': 3,
#   'causeOfDeath': 0,
#   'bulletHit': 1,
#   'time': 42.58439636230469},
#  {'isGettingSmall': False,
#   'bulletsFired': 1,
#   'bulletHit': 1,
#   'time': 32.275970458984375,
#   'causeOfDeath': 0,
#   'score': 10},
#  {'bulletsFired': 0,
#   'isGettingSmall': False,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 9,
#   'time': 27.762969970703125},
#  {'isGettingSmall': True,
#   'score': 19,
#   'bulletHit': 4,
#   'causeOfDeath': 3,
#   'time': 69.339111328125,
#   'bulletsFired': 10},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': False,
#   'score': 1,
#   'time': 4.60296630859375},
#  {'score': 38,
#   'isGettingSmall': False,
#   'bulletsFired': 9,
#   'bulletHit': 4,
#   'causeOfDeath': 3,
#   'time': 128.85296630859375},
#  {'bulletHit': 0,
#   'isGettingSmall': False,
#   'bulletsFired': 0,
#   'score': 0,
#   'time': 2.0809326171875,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 53.438079833984375,
#   'bulletHit': 0,
#   'score': 10},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 4.46710205078125,
#   'causeOfDeath': 0,
#   'score': 0,
#   'bulletHit': 0},
#  {'bulletHit': 2,
#   'bulletsFired': 4,
#   'score': 22,
#   'time': 135.4024658203125,
#   'causeOfDeath': 0,
#   'isGettingSmall': False},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 0,
#   'bulletsFired': 0,
#   'time': 4.267666816711426,
#   'isGettingSmall': True},
#  {'isGettingSmall': False,
#   'causeOfDeath': 3,
#   'time': 216.15301513671875,
#   'bulletsFired': 10,
#   'bulletHit': 4,
#   'score': 40},
#  {'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 1.9183526039123535},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 26.89348602294922,
#   'score': 5},
#  {'bulletsFired': 0,
#   'score': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 2.4736275672912598,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 0,
#   'time': 3.064857006072998,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 5.048399925231934},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 0,
#   'time': 2.1599998474121094,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'bulletsFired': 0,
#   'time': 2.014775276184082,
#   'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0},
#  {'score': 1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 5.8943634033203125},
#  {'score': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'time': 7.419999599456787,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 1,
#   'time': 30.399999618530273,
#   'score': 3,
#   'causeOfDeath': 0,
#   'bulletsFired': 1},
#  {'bulletHit': 0,
#   'time': 9.430404663085938,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': 1},
#  {'time': 33.11542892456055,
#   'score': 2,
#   'causeOfDeath': 0,
#   'bulletsFired': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'time': 8.654600143432617,
#   'isGettingSmall': True,
#   'score': 2,
#   'bulletHit': 0,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'score': 2,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'time': 30.043899536132812,
#   'bulletsFired': 0},
#  {'score': 0,
#   'time': 4.549900054931641,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'score': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'time': 1.281242847442627,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'bulletsFired': 0,
#   'time': 18.00201988220215,
#   'causeOfDeath': 0,
#   'score': 5,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'score': 1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'time': 2.6994400024414062},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'score': 7,
#   'bulletHit': 0,
#   'time': 19.518890380859375},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 10.298294067382812,
#   'score': 3,
#   'bulletsFired': 0,
#   'causeOfDeath': 0},
#  {'score': 12,
#   'bulletHit': 1,
#   'time': 36.78630065917969,
#   'causeOfDeath': 0,
#   'bulletsFired': 1,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 11,
#   'time': 103.89479064941406,
#   'causeOfDeath': 0,
#   'bulletsFired': 1},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 68.6453857421875,
#   'causeOfDeath': 0,
#   'score': 1},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 2,
#   'time': 9.26930046081543,
#   'causeOfDeath': 0},
#  {'score': 4,
#   'time': 10.176599502563477,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'score': 6,
#   'bulletsFired': 0,
#   'time': 20.4169979095459,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 7,
#   'bulletHit': 0,
#   'time': 17.34239959716797},
#  {'score': 5,
#   'isGettingSmall': False,
#   'bulletsFired': 4,
#   'bulletHit': 1,
#   'time': 96.88690185546875,
#   'causeOfDeath': 0},
#  {'time': 29.670799255371094,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 8,
#   'bulletHit': 0,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 22.95639991760254,
#   'causeOfDeath': 0,
#   'score': 2},
#  {'score': 1,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 41.401100158691406},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'time': 9.709999084472656,
#   'bulletHit': 0},
#  {'score': 2,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'time': 9.743000030517578,
#   'bulletsFired': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 3,
#   'time': 10.14900016784668,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'score': 2,
#   'time': 12.422000885009766,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'time': 13.942996978759766,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 3,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'score': 2,
#   'bulletsFired': 1,
#   'time': 44.77299499511719,
#   'bulletHit': 0,
#   'causeOfDeath': 0},
#  {'bulletHit': 0,
#   'time': 16.01300048828125,
#   'bulletsFired': 0,
#   'score': 2,
#   'causeOfDeath': 1,
#   'isGettingSmall': True},
#  {'causeOfDeath': 1,
#   'time': 40.08399963378906,
#   'isGettingSmall': True,
#   'score': 3,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 19.10089874267578,
#   'score': 3},
#  {'bulletsFired': 5,
#   'time': 35.91560363769531,
#   'causeOfDeath': 0,
#   'bulletHit': 3,
#   'score': 8,
#   'isGettingSmall': True},
#  {'time': 2.799999952316284,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'score': 1},
#  {'score': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 2.7200000286102295},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'score': 30,
#   'time': 83.24240112304688,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 83.24240112304688,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 30},
#  {'score': 6,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 19.299999237060547,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'time': 48.84000015258789,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'score': 18,
#   'bulletHit': 0},
#  {'time': 40.439998626708984,
#   'causeOfDeath': 0,
#   'score': 15,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'time': 12.991527557373047,
#   'bulletsFired': 0,
#   'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 1},
#  {'causeOfDeath': 0,
#   'time': 16.399999618530273,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 5},
#  {'score': 10,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 39.720829010009766,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'score': 2,
#   'causeOfDeath': 0,
#   'time': 11.139999389648438,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 3.359999895095825,
#   'isGettingSmall': True,
#   'score': 0},
#  {'score': 7,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 20.559999465942383},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 14,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 39.265594482421875},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 20,
#   'time': 54.94188690185547,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 54.94188690185547,
#   'causeOfDeath': -1,
#   'score': 20},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 54.94188690185547,
#   'score': 20,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 20,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 54.94188690185547},
#  {'time': 54.94188690185547,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 20,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 20,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 54.94188690185547},
#  {'isGettingSmall': True,
#   'score': 20,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'time': 54.94188690185547,
#   'bulletsFired': 0},
#  {'score': 20,
#   'time': 54.94188690185547,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'time': 54.94188690185547,
#   'score': 20,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'score': 20,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 54.94188690185547,
#   'bulletHit': 0},
#  {'time': 54.94188690185547,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 20},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 20,
#   'time': 54.94188690185547,
#   'causeOfDeath': -1},
#  {'score': 1,
#   'time': 12.895496368408203,
#   'bulletsFired': 0,
#   'causeOfDeath': 1,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'score': 14,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'time': 44.01811599731445,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 51.429237365722656,
#   'bulletHit': 0,
#   'score': 16},
#  {'score': 0,
#   'bulletsFired': 0,
#   'time': 4.559999942779541,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 8.619999885559082,
#   'causeOfDeath': 0,
#   'score': 2},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 1,
#   'time': 4.299999713897705,
#   'bulletsFired': 0},
#  {'time': 3.359999895095825,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 1,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'score': 3,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 8.979999542236328,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'time': 15.75999927520752,
#   'causeOfDeath': 0,
#   'score': 6,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'score': 5,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 15.859999656677246,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'score': 4,
#   'time': 10.84000015258789,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'time': 9.16888427734375,
#   'score': 0,
#   'bulletsFired': 0},
#  {'score': 2,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 6.583099365234375},
#  {'time': 18.24951171875,
#   'bulletHit': 0,
#   'causeOfDeath': 1,
#   'score': 2,
#   'bulletsFired': 1,
#   'isGettingSmall': True},
#  {'score': 4,
#   'bulletHit': 0,
#   'time': 14.777389526367188,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 2},
#  {'time': 13.82049560546875,
#   'isGettingSmall': True,
#   'bulletsFired': 1,
#   'bulletHit': 0,
#   'score': 4,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'time': 26.858200073242188,
#   'bulletsFired': 2,
#   'bulletHit': 0,
#   'score': 4,
#   'isGettingSmall': True},
#  {'time': 31.101806640625,
#   'isGettingSmall': True,
#   'score': 5,
#   'bulletHit': 0,
#   'causeOfDeath': 1,
#   'bulletsFired': 4},
#  {'time': 29.18385124206543,
#   'causeOfDeath': -1,
#   'score': 10,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'score': 10,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'time': 29.18385124206543,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'score': 8,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 23.36172103881836,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 8,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 23.36172103881836},
#  {'isGettingSmall': True,
#   'score': 8,
#   'time': 23.36172103881836,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0},
#  {'time': 14.679999351501465,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 6},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 12,
#   'bulletHit': 0,
#   'time': 46.03085708618164},
#  {'bulletHit': 0,
#   'time': 46.03085708618164,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 12,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 12,
#   'time': 46.03085708618164},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 2,
#   'time': 14.962281227111816,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 2,
#   'bulletsFired': 0,
#   'time': 14.962281227111816},
#  {'bulletsFired': 0,
#   'score': 5,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 15.440482139587402,
#   'causeOfDeath': -1},
#  {'bulletHit': 0,
#   'causeOfDeath': 1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 10.00089168548584,
#   'score': 0},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 5.681517124176025,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 0},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 5.681517124176025},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 49.64236831665039,
#   'score': 17,
#   'bulletHit': 0},
#  {'score': 3,
#   'bulletsFired': 0,
#   'time': 22.526893615722656,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'time': 22.526893615722656,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 3,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 14.841033935546875,
#   'causeOfDeath': -1,
#   'score': 4},
#  {'bulletsFired': 0,
#   'score': 4,
#   'time': 14.841033935546875,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 14.841033935546875,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 4},
#  {'score': 4,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 14.841033935546875},
#  {'time': 9.94267463684082,
#   'bulletHit': 0,
#   'score': 2,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'score': 2,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 9.94267463684082,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 2.771333932876587,
#   'isGettingSmall': True,
#   'score': 0},
#  {'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'score': 2,
#   'time': 8.715362548828125,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'time': 6.458073139190674,
#   'causeOfDeath': 0,
#   'score': 2,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'score': 3,
#   'time': 10.280621528625488,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'time': 10.280621528625488,
#   'causeOfDeath': -1,
#   'score': 3,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 10.280621528625488,
#   'score': 3,
#   'isGettingSmall': True,
#   'causeOfDeath': -1},
#  {'bulletHit': 0,
#   'score': 3,
#   'time': 10.280621528625488,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 3,
#   'isGettingSmall': True,
#   'time': 10.280621528625488},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 3,
#   'time': 10.280621528625488},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 3,
#   'bulletHit': 0,
#   'time': 10.280621528625488,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 12.827552795410156,
#   'score': 3},
#  {'isGettingSmall': True,
#   'score': 3,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 12.827552795410156,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 2.8166236877441406,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 5.699999809265137,
#   'score': 1,
#   'causeOfDeath': 0,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'time': 11,
#   'score': 5,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.506195068359375,
#   'score': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'score': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 5.506195068359375,
#   'causeOfDeath': -1,
#   'isGettingSmall': True},
#  {'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'time': 5.506195068359375},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 1,
#   'causeOfDeath': -1,
#   'time': 6.010448455810547,
#   'bulletHit': 0},
#  {'score': 1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'time': 6.010448455810547},
#  {'causeOfDeath': -1,
#   'score': 1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 6.010448455810547},
#  {'causeOfDeath': -1,
#   'score': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 6.010448455810547},
#  {'time': 6.010448455810547,
#   'causeOfDeath': -1,
#   'score': 1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 16.29386329650879,
#   'score': 2,
#   'causeOfDeath': 1},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 30.206623077392578,
#   'bulletHit': 0,
#   'score': 11},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 17.84037971496582,
#   'bulletHit': 0,
#   'score': 6},
#  {'isGettingSmall': True,
#   'score': 6,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 17.84037971496582},
#  {'bulletHit': 0,
#   'score': 6,
#   'causeOfDeath': -1,
#   'time': 17.84037971496582,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'time': 17.84037971496582,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 6},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 17.84037971496582,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 6},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 6,
#   'time': 17.84037971496582,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 6,
#   'isGettingSmall': True,
#   'time': 17.84037971496582,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'score': 6,
#   'bulletsFired': 0,
#   'time': 17.84037971496582,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 43.56310272216797,
#   'bulletHit': 0,
#   'score': 15,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15,
#   'bulletsFired': 0,
#   'time': 43.56310272216797},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'score': 15},
#  {'score': 15,
#   'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15,
#   'bulletHit': 0,
#   'time': 43.56310272216797},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 15,
#   'bulletHit': 0,
#   'time': 43.56310272216797},
#  {'score': 15,
#   'time': 43.56310272216797,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1,
#   'score': 15},
#  {'isGettingSmall': True,
#   'score': 15,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 43.56310272216797},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'score': 15,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'time': 43.56310272216797,
#   'score': 15,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 15,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1},
#  {'score': 15,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 43.56310272216797},
#  {'score': 15,
#   'bulletsFired': 0,
#   'time': 43.56310272216797,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'time': 43.56310272216797,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 15,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'score': 15,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'isGettingSmall': True},
#  {'time': 43.56310272216797,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 15,
#   'causeOfDeath': -1},
#  {'time': 43.56310272216797,
#   'score': 15,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'time': 43.56310272216797,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 15},
#  {'score': 15,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15,
#   'bulletsFired': 0,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'score': 15,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 43.56310272216797},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'bulletHit': 0,
#   'score': 15},
#  {'causeOfDeath': -1,
#   'time': 43.56310272216797,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 15,
#   'bulletsFired': 0},
#  {'score': 15,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 43.56310272216797,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'time': 43.56310272216797,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'time': 43.56310272216797},
#  {'isGettingSmall': True,
#   'score': 15,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'score': 15,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 15,
#   'causeOfDeath': -1,
#   'time': 43.56310272216797,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 43.56310272216797,
#   'score': 15},
#  {'score': 15,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'time': 43.56310272216797,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'score': 15,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'score': 15,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1},
#  {'time': 43.56310272216797,
#   'causeOfDeath': -1,
#   'score': 15,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'isGettingSmall': True,
#   'score': 15},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 15,
#   'time': 43.56310272216797,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 15,
#   'causeOfDeath': -1,
#   'time': 43.56310272216797},
#  {'bulletsFired': 0,
#   'time': 43.56310272216797,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 15,
#   'isGettingSmall': True},
#  {'score': 15,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'isGettingSmall': True,
#   'causeOfDeath': -1},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 43.56310272216797,
#   'score': 15},
#  {'score': 15,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 43.56310272216797},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 15,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 43.56310272216797},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'score': 15},
#  {'time': 43.56310272216797,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 15,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 43.56310272216797,
#   'causeOfDeath': -1,
#   'score': 15},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 43.56310272216797,
#   'score': 15,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'score': 8,
#   'time': 19.71875},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 8,
#   'time': 19.71875,
#   'causeOfDeath': -1,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'score': 0,
#   'bulletHit': 0,
#   'time': 5.924981117248535,
#   'causeOfDeath': 0,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 2.6026101112365723,
#   'causeOfDeath': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 7,
#   'time': 21.26744270324707,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 7,
#   'time': 21.26744270324707,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'score': 7,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 21.26744270324707,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 7,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 21.26744270324707},
#  {'score': 0,
#   'bulletHit': 0,
#   'time': 5.497236251831055,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': -1,
#   'score': 0,
#   'bulletsFired': 0,
#   'time': 5.497236251831055,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'causeOfDeath': 3,
#   'score': 3,
#   'time': 23.101593017578125,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'time': 9.881210327148438,
#   'bulletHit': 0,
#   'score': 2},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'time': 10.948501586914062,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 2},
#  {'score': 0,
#   'time': 7.979278564453125,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'score': 4,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 17.594696044921875,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 4,
#   'time': 17.594696044921875,
#   'bulletHit': 0},
#  {'score': 4,
#   'bulletsFired': 0,
#   'time': 17.594696044921875,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True},
#  {'score': 13,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 38.20196533203125},
#  {'score': 19,
#   'isGettingSmall': True,
#   'time': 51.905059814453125,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'bulletsFired': 0},
#  {'time': 51.905059814453125,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 19},
#  {'causeOfDeath': 0,
#   'score': 19,
#   'bulletHit': 0,
#   'time': 51.905059814453125,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 51.905059814453125,
#   'score': 19,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 19,
#   'time': 51.905059814453125},
#  {'time': 51.905059814453125,
#   'isGettingSmall': True,
#   'score': 19,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'time': 51.905059814453125,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 19,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 19,
#   'time': 51.905059814453125},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 51.905059814453125,
#   'causeOfDeath': 0,
#   'score': 19,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 19,
#   'causeOfDeath': 0,
#   'time': 51.905059814453125,
#   'bulletHit': 0},
#  {'score': 19,
#   'causeOfDeath': 0,
#   'time': 51.905059814453125,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'time': 51.905059814453125,
#   'bulletHit': 0,
#   'score': 19,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'score': 19,
#   'bulletsFired': 0,
#   'time': 51.905059814453125,
#   'causeOfDeath': 0,
#   'bulletHit': 0},
#  {'causeOfDeath': 0,
#   'score': 19,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 51.905059814453125,
#   'bulletsFired': 0},
#  {'score': 19,
#   'bulletsFired': 0,
#   'time': 51.905059814453125,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 19,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 51.905059814453125},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 19,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 51.905059814453125},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 6.1595458984375,
#   'score': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'time': 6.1595458984375,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 1},
#  {'score': 19,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'time': 51.905059814453125,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'score': 19,
#   'bulletsFired': 0,
#   'time': 51.905059814453125,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'score': 19,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 51.905059814453125},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 19,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 51.905059814453125},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 51.905059814453125,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 19},
#  {'bulletHit': 0,
#   'score': 19,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 51.905059814453125},
#  {'isGettingSmall': True,
#   'score': 4,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'time': 12.959808349609375,
#   'bulletHit': 0},
#  {'score': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletsFired': 0,
#   'time': 3.572296142578125},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 9.553802490234375,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 1},
#  {'score': 11,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 3,
#   'time': 42.45281982421875,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 5.869171142578125,
#   'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'time': 5.869171142578125,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'time': 5.869171142578125,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'bulletsFired': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.869171142578125},
#  {'score': 14,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 42.9227294921875},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'score': 14,
#   'time': 42.9227294921875,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 42.9227294921875,
#   'causeOfDeath': -1,
#   'score': 14},
#  {'isGettingSmall': True,
#   'score': 14,
#   'causeOfDeath': -1,
#   'time': 42.9227294921875,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 14,
#   'time': 42.9227294921875,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 14,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 42.9227294921875},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 14,
#   'time': 42.9227294921875},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 14,
#   'time': 42.9227294921875,
#   'bulletsFired': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 13.0198974609375,
#   'causeOfDeath': 1,
#   'score': 1,
#   'bulletHit': 0},
#  {'causeOfDeath': 0,
#   'bulletHit': 0,
#   'time': 35.51708984375,
#   'score': 12,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': 3,
#   'isGettingSmall': True,
#   'time': 19.281982421875,
#   'score': 1},
#  {'score': 6,
#   'time': 19.954345703125,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 12,
#   'bulletHit': 0,
#   'time': 35.707275390625},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 12,
#   'causeOfDeath': -1,
#   'time': 35.707275390625},
#  {'causeOfDeath': -1,
#   'time': 35.707275390625,
#   'score': 12,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 35.707275390625,
#   'score': 12},
#  {'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'score': 10,
#   'bulletHit': 0,
#   'time': 26.67333984375,
#   'bulletsFired': 0},
#  {'time': 31.99951171875,
#   'score': 12,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'time': 22.5753173828125,
#   'causeOfDeath': -1,
#   'score': 10,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'score': 10,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 22.5753173828125},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 10,
#   'bulletHit': 0,
#   'time': 22.5753173828125},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 22.5753173828125,
#   'score': 10},
#  {'bulletHit': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 8,
#   'bulletsFired': 0,
#   'time': 18.63970947265625},
#  {'time': 12.6854248046875,
#   'causeOfDeath': 3,
#   'bulletHit': 0,
#   'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'time': 31.8414306640625,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'score': 15},
#  {'isGettingSmall': True,
#   'score': 8,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 19.07415771484375,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'time': 19.07415771484375,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 8},
#  {'bulletsFired': 0,
#   'score': 8,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 19.07415771484375,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 8,
#   'isGettingSmall': True,
#   'time': 19.07415771484375,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'score': 8,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 19.07415771484375,
#   'bulletHit': 0},
#  {'time': 19.07415771484375,
#   'causeOfDeath': -1,
#   'score': 8,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 31.4798583984375,
#   'score': 13,
#   'bulletHit': 0},
#  {'time': 54.5167236328125,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 17},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.620051860809326,
#   'isGettingSmall': True},
#  {'score': 1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 13.003585815429688,
#   'causeOfDeath': 1,
#   'isGettingSmall': True},
#  {'causeOfDeath': 0,
#   'time': 2.60341739654541,
#   'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 4.516504287719727,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': 0},
#  {'isGettingSmall': True,
#   'time': 9.938699722290039,
#   'bulletsFired': 0,
#   'causeOfDeath': 1,
#   'score': 0,
#   'bulletHit': 0},
#  {'score': 8,
#   'time': 39.36000061035156,
#   'causeOfDeath': 3,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'time': 2.524509906768799},
#  {'time': 62.81999969482422,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 24},
#  {'score': 1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'time': 2.4800000190734863,
#   'bulletHit': 0},
#  {'causeOfDeath': 0,
#   'score': 0,
#   'time': 2.440000057220459,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 2.4800000190734863},
#  {'time': 5.360184192657471,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 18.275009155273438,
#   'causeOfDeath': -1,
#   'score': 6,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 18.275009155273438,
#   'score': 6},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 18.275009155273438,
#   'score': 6,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'time': 56.210716247558594,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': 0,
#   'score': 19},
#  {'isGettingSmall': True,
#   'time': 56.210716247558594,
#   'bulletHit': 0,
#   'score': 19,
#   'bulletsFired': 0,
#   'causeOfDeath': 0},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 56.210716247558594,
#   'isGettingSmall': True,
#   'score': 19,
#   'causeOfDeath': 0},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': -1,
#   'time': 5.821460723876953},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.821460723876953},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 1,
#   'bulletsFired': 0,
#   'time': 35.94344711303711},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 1,
#   'bulletsFired': 0,
#   'time': 35.94344711303711,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'score': 1,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'time': 35.94344711303711,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'time': 35.94344711303711,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 1},
#  {'time': 8.220748901367188,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 0,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'time': 8.220748901367188,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 0,
#   'time': 8.220748901367188},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 8.220748901367188,
#   'score': 0,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': -1,
#   'time': 5.660765171051025,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 0,
#   'time': 5.660765171051025},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 5.660765171051025,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.660765171051025,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.660765171051025},
#  {'bulletHit': 0,
#   'score': 0,
#   'time': 5.660765171051025,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'time': 5.660765171051025,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'score': 0},
#  {'causeOfDeath': -1,
#   'time': 5.660765171051025,
#   'bulletHit': 0,
#   'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'time': 5.660765171051025,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0},
#  {'bulletHit': 0,
#   'time': 5.660765171051025,
#   'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1},
#  {'bulletsFired': 0,
#   'time': 5.660765171051025,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0},
#  {'score': 0,
#   'causeOfDeath': -1,
# ...
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 5.572074890136719},
#  {'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': -1,
#   'time': 5.572074890136719,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'score': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 5.572074890136719,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'time': 5.572074890136719,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'score': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True},
#  {'score': 8,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 38.943939208984375},
#  {'isGettingSmall': True,
#   'score': 8,
#   'causeOfDeath': -1,
#   'time': 38.943939208984375,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.572074890136719},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 6.420543670654297,
#   'bulletsFired': 0,
#   'score': 0},
#  {'causeOfDeath': -1,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 6.420543670654297},
#  {'isGettingSmall': True,
#   'time': 6.420543670654297,
#   'score': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'score': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 5.572074890136719,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'score': 0,
#   'bulletHit': 0,
#   'time': 6.420543670654297,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 6.420543670654297,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'score': 0},
#  {'score': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 6.420543670654297,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'time': 6.420543670654297,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 0},
#  {'time': 6.420543670654297,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0},
#  {'bulletsFired': 0,
#   'time': 5.572074890136719,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.572074890136719,
#   'bulletHit': 0},
#  {'time': 5.572074890136719,
#   'score': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'score': 0,
#   'time': 5.572074890136719,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 0,
#   'time': 5.572074890136719,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'time': 5.572074890136719,
#   'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 5.9214630126953125,
#   'score': 1,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'score': 1,
#   'time': 5.9214630126953125,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'score': 1,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 5.9214630126953125,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 1,
#   'time': 5.9214630126953125},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.9214630126953125,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 1},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 5.9214630126953125},
#  {'time': 5.74208402633667,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 0},
#  {'causeOfDeath': -1,
#   'time': 5.74208402633667,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0},
#  {'score': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.74208402633667},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'time': 5.74208402633667},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0,
#   'time': 5.74208402633667,
#   'bulletHit': 0},
#  {'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.74208402633667,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.74208402633667},
#  {'bulletsFired': 0,
#   'time': 5.74208402633667,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'time': 5.74208402633667,
#   'score': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'time': 5.74208402633667,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'score': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'score': 0,
#   'bulletsFired': 0,
#   'time': 5.74208402633667,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 5.74208402633667,
#   'bulletsFired': 0},
#  {'score': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 5.74208402633667,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0,
#   'time': 5.74208402633667},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 5.74208402633667},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 5.74208402633667,
#   'causeOfDeath': -1,
#   'score': 0,
#   'bulletHit': 0},
#  {'time': 5.775491237640381,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'score': 0,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 5.775491237640381,
#   'bulletHit': 0,
#   'score': 0,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'time': 5.775491237640381,
#   'bulletsFired': 0,
#   'score': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 33.40437316894531,
#   'isGettingSmall': True,
#   'score': 9,
#   'causeOfDeath': -1},
#  {'time': 33.40437316894531,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'score': 9,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'time': 5.566938877105713,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'score': 0,
#   'time': 5.566938877105713,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'score': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'time': 5.862490653991699},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'time': 5.862490653991699,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 5.679283142089844,
#   'bulletsFired': 0,
#   'score': 0},
#  {'time': 5.679283142089844,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'score': 0,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 5.679283142089844,
#   'score': 0},
#  {'causeOfDeath': -1,
#   'score': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 5.862490653991699},
#  {'time': 7.501034259796143,
#   'score': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1},
#  {'bulletHit': 0,
#   'time': 7.501034259796143,
#   'causeOfDeath': -1,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'time': 7.501034259796143,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'score': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 7.501034259796143},
#  {'time': 25.28136444091797,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 9,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'time': 25.28136444091797,
#   'score': 9},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 9,
#   'time': 25.28136444091797,
#   'causeOfDeath': -1,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'bulletHit': 0,
#   'score': 11,
#   'time': 28.087566375732422,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'time': 10.968761444091797,
#   'score': 2,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'time': 10.968761444091797,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 2},
#  {'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 2,
#   'bulletsFired': 0,
#   'time': 10.968761444091797,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'score': 2,
#   'causeOfDeath': -1,
#   'time': 10.968761444091797,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 10.968761444091797,
#   'score': 2,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'score': 9,
#   'time': 32.861881256103516,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'score': 9,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 32.861881256103516},
#  {'causeOfDeath': -1,
#   'time': 5.205111026763916,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0},
#  {'bulletHit': 0,
#   'score': 0,
#   'time': 5.205111026763916,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 5.205111026763916,
#   'score': 0,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.205111026763916,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'time': 5.683834552764893,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0},
#  {'time': 5.683834552764893,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 0},
#  {'time': 5.683834552764893,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 0},
#  {'score': 9,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'time': 23.741466522216797,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'bulletHit': 0,
#   'score': 9,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 23.741466522216797,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'score': 9,
#   'isGettingSmall': True,
#   'time': 23.741466522216797},
#  {'isGettingSmall': True,
#   'score': 9,
#   'time': 23.741466522216797,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 5.540047645568848,
#   'score': 0},
#  {'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.540047645568848},
#  {'causeOfDeath': -1,
#   'score': 0,
#   'time': 5.540047645568848,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0},
#  {'score': 6,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 22.326501846313477},
#  {'score': 6,
#   'isGettingSmall': True,
#   'bulletHit': 0,
#   'bulletsFired': 0,
#   'time': 22.326501846313477,
#   'causeOfDeath': -1},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'score': 6,
#   'bulletsFired': 0,
#   'time': 22.326501846313477,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 5,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 15.742610931396484},
#  {'causeOfDeath': -1,
#   'time': 15.742610931396484,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 5},
#  {'bulletHit': 0,
#   'score': 0,
#   'causeOfDeath': -1,
#   'time': 5.699472427368164,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'time': 5.699472427368164,
#   'bulletHit': 0,
#   'score': 0},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 5.699472427368164,
#   'bulletsFired': 0,
#   'score': 0},
#  {'isGettingSmall': True,
#   'score': 15,
#   'causeOfDeath': 0,
#   'time': 44.55999755859375,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'time': 22.34000015258789,
#   'bulletsFired': 0,
#   'score': 7,
#   'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'time': 9.558113098144531,
#   'score': 2,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True},
#  {'score': 2,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 9.558113098144531,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'time': 9.558113098144531,
#   'bulletHit': 0,
#   'score': 2},
#  {'isGettingSmall': True,
#   'score': 2,
#   'causeOfDeath': -1,
#   'time': 9.558113098144531,
#   'bulletsFired': 0,
#   'bulletHit': 0},
#  {'causeOfDeath': -1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'score': 2,
#   'time': 9.558113098144531},
#  {'bulletHit': 0,
#   'score': 20,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 0,
#   'time': 44.2599983215332},
#  {'time': 40.37331771850586,
#   'bulletHit': 0,
#   'score': 13,
#   'bulletsFired': 0,
#   'causeOfDeath': 0,
#   'isGettingSmall': True},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 23.805095672607422,
#   'score': 8,
#   'bulletsFired': 0,
#   'causeOfDeath': -1},
#  {'time': 23.805095672607422,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'score': 8,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'causeOfDeath': 1,
#   'bulletsFired': 0,
#   'time': 10.000955581665039,
#   'bulletHit': 0,
#   'score': 0},
#  {'causeOfDeath': 0,
#   'isGettingSmall': True,
#   'time': 2.440000057220459,
#   'score': 0,
#   'bulletHit': 0,
#   'bulletsFired': 0},
#  {'time': 13.005638122558594,
#   'score': 1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'causeOfDeath': 1,
#   'bulletHit': 0},
#  {'score': 0,
#   'bulletsFired': 0,
#   'time': 5.5237956047058105,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'isGettingSmall': True,
#   'time': 5.5237956047058105},
#  {'time': 5.5237956047058105,
#   'isGettingSmall': True,
#   'score': 0,
#   'bulletsFired': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1},
#  {'isGettingSmall': True,
#   'score': 0,
#   'bulletHit': 0,
#   'time': 5.5237956047058105,
#   'causeOfDeath': -1,
#   'bulletsFired': 0},
#  {'time': 10.018575668334961,
#   'bulletHit': 0,
#   'causeOfDeath': 1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 0},
#  {'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'score': 0,
#   'time': 5.5237956047058105,
#   'bulletHit': 0},
#  {'time': 5.5237956047058105,
#   'score': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True,
#   'bulletHit': 0},
#  {'bulletsFired': 0,
#   'isGettingSmall': True,
#   'score': 0,
#   'causeOfDeath': -1,
#   'bulletHit': 0,
#   'time': 5.5237956047058105},
#  {'time': 21.061376571655273,
#   'score': 0,
#   'bulletHit': 0,
#   'causeOfDeath': -1,
#   'bulletsFired': 0,
#   'isGettingSmall': True},
#  {'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'score': 0,
#   'bulletHit': 0,
#   'time': 21.061376571655273},
#  {'score': 0,
#   'causeOfDeath': -1,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'time': 21.061376571655273,
#   'bulletHit': 0},
#  {'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': -1,
#   'time': 21.061376571655273,
#   'score': 0},
#  {'time': 6.480000019073486,
#   'score': 1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'bulletsFired': 0,
#   'causeOfDeath': 0},
#  {'causeOfDeath': 1,
#   'bulletHit': 0,
#   'isGettingSmall': True,
#   'time': 13.029073715209961,
#   'bulletsFired': 0,
#   'score': 1}]

# %%
len(json_response_level2['data'])
# Out:
# 515

# %%
import matplotlib.pyplot as plt

data = json_response_level2['data']

# initialize the counter for each cause of death
causeOfDeath_0_count = 0
causeOfDeath_1_count = 0
causeOfDeath_3_count = 0

# count the number of deaths for each cause of death
for d in data:
    if d['causeOfDeath'] == 0:
        causeOfDeath_0_count += 1
    elif d['causeOfDeath'] == 1:
        causeOfDeath_1_count += 1

# create a list of the counts for each cause of death
counts = [causeOfDeath_0_count, causeOfDeath_1_count]

# create a list of the labels for each cause of death
labels = ['Enemy', 'Size']

# create a list of colors for the pie chart
colors = ['red', 'green']

# create the pie chart
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# add a title to the chart
plt.title('Causes of Death')

# show the chart
plt.show()

# %%
import matplotlib.pyplot as plt


# Filter the data based on causeOfDeath field
causeOfDeath01 = [d['time'] for d in json_response_level2['data'] if d['causeOfDeath'] in [0, 1]]
causeOfDeath3 = [d['time'] for d in json_response_level1['data'] if d['causeOfDeath'] == 3]

# Set the bin size and range for the histogram
bin_size = 20
range_min = min(min(causeOfDeath01), min(causeOfDeath3))
range_max = max(max(causeOfDeath01), max(causeOfDeath3))

# Create two separxate histograms
fig, (ax1, ax2) = plt.subplots(2, 1,figsize=(8, 8))

ax1.hist(causeOfDeath01, bins=int((range_max-range_min)/bin_size), range=(range_min, range_max), color='green',edgecolor='black')
ax1.set_title('Histogram for causeOfDeath=0 or 1')
ax1.set_xlabel('Time')
ax1.set_ylabel('Count')
ax1.set_xlim(0, 150)
ax1.set_ylim(0, 150)

ax2.hist(causeOfDeath3, bins=int((range_max-range_min)/bin_size), range=(range_min, range_max), color='blue', edgecolor='black')
ax2.set_title('Histogram for causeOfDeath=3')
ax2.set_xlabel('Time')
ax2.set_ylabel('Count')
ax2.set_xlim(0, 150)
ax2.set_ylim(0, 150)
plt.tight_layout()
plt.show()

# %%
# import matplotlib.pyplot as plt

# # Create two lists of game times for causeOfDeath=0 or 1 and causeOfDeath=3
# game_times_cause01 = [d['time'] for d in data if d['causeOfDeath'] in [0, 1]]
# game_times_cause3 = [d['time'] for d in data if d['causeOfDeath'] == 3]

# # Define the bin size and range for the histograms
# bin_size = 20
# bin_range = (0, 200)

# # Create the histogram for causeOfDeath=0 or 1
# plt.hist(game_times_cause01, bins=int((bin_range[1]-bin_range[0])/bin_size), range=bin_range, color='blue', alpha=0.5)
# # Create the histogram for causeOfDeath=3
# plt.hist(game_times_cause3, bins=int((bin_range[1]-bin_range[0])/bin_size), range=bin_range, color='red', alpha=0.5)

# # Add labels and titles
# plt.xlabel('Game Time')
# plt.ylabel('Number of Games')
# plt.title('Histogram of Game Time by Cause of Death')

# # Show the plot
# plt.show()

# %%
import matplotlib.pyplot as plt

# sample data
data = json_response_level2['data']
# filter data
filtered_data = [d for d in data if d.get('causeOfDeath') == 3]

# calculate percentages
num_true = sum(1 for d in filtered_data if d.get('isGettingSmall') is True)
num_false = sum(1 for d in filtered_data if d.get('isGettingSmall') is False)
total = num_true + num_false
percent_true = num_true / total * 100
percent_false = num_false / total * 100

# plot pie chart
fig, ax = plt.subplots()
ax.pie([percent_true, percent_false], labels=['Shrinking', 'Infinite health'], autopct='%1.1f%%')
ax.set_title('Percentage of isGettingSmall=True or False where causeOfDeath=3')
plt.show()

# %%
import matplotlib.pyplot as plt

data = json_response_level2['data']

# Create lists to hold the x and y values for each category
x_vals_0 = []
y_vals_0 = []
x_vals_1 = []
y_vals_1 = []
x_vals_3 = []
y_vals_3 = []
plt.figure(figsize=(9, 7))

# Populate the lists based on the value of causeOfDeath
for entry in data:
    if entry['causeOfDeath'] == 0:
        x_vals_0.append(entry['time'])
        y_vals_0.append(entry['score'])
    elif entry['causeOfDeath'] == 1:
        x_vals_1.append(entry['time'])
        y_vals_1.append(entry['score'])
    elif entry['causeOfDeath'] == 3:
        x_vals_3.append(entry['time'])
        y_vals_3.append(entry['score'])

# Create the scatter plots for each category
scatter_0 = plt.scatter(x_vals_0, y_vals_0, c='blue', label='Enemy Attack')
scatter_1 = plt.scatter(x_vals_1, y_vals_1, c='green', label='Diminshed Size')
scatter_3 = plt.scatter(x_vals_3, y_vals_3, c='red', label='Winners')

# Add axis labels and a title
plt.xlabel('Time')
plt.ylabel('Score')
plt.title('Score vs. Time with Win State')
plt.xlim(0, 120)

# Add a legend for the causeOfDeath categories
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles, labels=labels)

# Display the plot
plt.show()
